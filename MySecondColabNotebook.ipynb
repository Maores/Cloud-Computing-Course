# %%
# @title Default title text
sleeptime = 4 # @param {"type":"integer"}

# %%
import time
print(time.ctime())
time.sleep(sleeptime)
print (time.ctime())
# Out:
# Tue Oct 28 09:03:54 2025
# Tue Oct 28 09:03:58 2025

# %%
name = "Cloud course" #@param {type:"string"}
print(name)
# Out:
# Cloud course

# %%
 color = 'red' #@param ["red", "green", "blue"]
 print(color)
# Out:
# red

# %%
 #@title Date fields
date_input = '2115-01-06' #@param {type:"date"}
print(date_input)
# Out:
# 2019-06-03

# %%
#@title Default title text
 # %%html
 <style>
 body {
 background-color: #f2bcca;
 }
 </style>
 color = 'green' #@param ["red", "green", "blue"] print(color)
 <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
 <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fi
 ll-opacity:1.0" />
 <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fi
 ll-opacity:1.0;" />
 <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fi
 ll-opacity:1.0;" />
 </svg>
# Out:
# <style>
# body {
# background-color: #f2bcca;
# }
# </style>
# color = 'green' #@param ["red", "green", "blue"] print(color)
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
# <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fi
# ll-opacity:1.0" />
# <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fi
# ll-opacity:1.0;" />
# <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fi
# ll-opacity:1.0;" />
# </svg>

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
with open('1.txt' , 'r') as file:
  contents = file.read()
  print(contents)
# Out:
# One
# Two
# Three

# %%
with open('1.txt' , 'r') as file:
  lines = file.readlines()
  print(lines)
# Out:
# ['One\n', 'Two\n', 'Three']

# %%
 file.close()

# %%
with open('/content/drive/My Drive/example.txt', 'a') as file:
 file.write('This is some example text.')

# %%
with open('/content/drive/My Drive/example.txt', 'a') as file:
  file.write('\nThis is some more example text.')

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked(b):
    # Display the message within the output widget.
     with output:
        with open('/content/drive/My Drive/1.txt', 'r') as file:
          contents = file.read()
          print(contents)

button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()

# %%
 import ipywidgets as widgets
 slider = widgets.IntSlider(value=5, max=10)
 display(slider)
# Out:
# IntSlider(value=5, max=10)

# %%
# @title Default title text
student = "" # @param [""] {"allow-input":true}
with open('student.txt' , 'r') as file:
  contents = file.read()
  print(contents)
# Out:
# Maor Saban Maor.Saban@e.braude.ac.il  CloudComputing https://www.youtube.com/
#
# Gilboa Natan Gilboa.Natan@e.braude.ac.il Algorithms https://www.taasuka.gov.il/he/Applicants/Pages/coronavirusUnpaidVacation.aspx

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Step 1: Load student data
students_data = {}
try:
    with open('student.txt', 'r') as file:
        for line in file:
            parts = line.strip( ).split()
            if len(parts) >= 4: # Assuming the format is Name Email Courses Link
                name = parts[0] + " " + parts[1] # Assuming name is first two parts
                email = parts[2]
                courses = parts[3]
                link = parts[4] if len(parts) > 4 else "N/A" # Handle case with no link
                students_data[name] = {
                    'email': email,
                    'courses': courses,
                    'link': link
                }
except FileNotFoundError:
    print("Error: student.txt not found.")
    students_data = {} # Initialize empty if file not found

# Step 2: Create dropdown menu
student_names = list(students_data.keys())
dropdown = widgets.Dropdown(
    options=student_names,
    description='Select student :',
    disabled=False,
)

# Step 3: Create output area
output = widgets.Output()

# Step 4: Handle dropdown selection
def on_student_select(change):
    with output:
        clear_output()
        selected_name = change['new']
        if selected_name in students_data:
            student_info = students_data[selected_name]
            print(f"Name: {selected_name}")
            print(f"Email: {student_info['email']}")
            print(f"Courses: {student_info['courses']}")
            print(f"Link: {student_info['link']}")
        else:
            print("No student has been found.")

dropdown.observe(on_student_select, names='value')

# Step 5: Display widgets
display(dropdown, output)
# Out:
# Error: student.txt not found.
# Dropdown(description='Select student :', options=(), value=None)
# Output()
